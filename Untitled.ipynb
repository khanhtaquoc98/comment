# %%
from __future__ import print_function
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
import pandas as pd
from pyvi import ViTokenizer
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
import re
import string
import codecs

# %%
path_nag = 'sentiment_dicts/nag.txt'
path_pos = 'sentiment_dicts/pos.txt'
path_not = 'sentiment_dicts/not.txt'

#Đóc các từ tích cực (pos), tiêu cực (nag), và các từ chỉ phủ định (not)
with codecs.open(path_nag, 'r',  encoding="utf8") as f:
    nag = f.readlines()
nag_list = [n.replace('\n', '') for n in nag]

with codecs.open(path_pos, 'r',  encoding="utf8") as f:
    pos = f.readlines()
pos_list = [n.replace('\n', '') for n in pos]
with codecs.open(path_not, 'r',  encoding="utf8") as f:
    not_ = f.readlines()
not_list = [n.replace('\n', '') for n in not_]

#print('Tích cực: ', pos_list)
#print('Tiêu cực: ', nag_list)
#print('Phủ định: ', not_list)

# %%
VN_CHARS_LOWER = u'ạảãàáâậầấẩẫăắằặẳẵóòọõỏôộổỗồốơờớợởỡéèẻẹẽêếềệểễúùụủũưựữửừứíìịỉĩýỳỷỵỹđð'
VN_CHARS_UPPER = u'ẠẢÃÀÁÂẬẦẤẨẪĂẮẰẶẲẴÓÒỌÕỎÔỘỔỖỒỐƠỜỚỢỞỠÉÈẺẸẼÊẾỀỆỂỄÚÙỤỦŨƯỰỮỬỪỨÍÌỊỈĨÝỲỶỴỸÐĐ'
VN_CHARS = VN_CHARS_LOWER + VN_CHARS_UPPER

def no_marks(s):
    __INTAB = [ch for ch in VN_CHARS]
    __OUTTAB = "a"*17 + "o"*17 + "e"*11 + "u"*11 + "i"*5 + "y"*5 + "d"*2
    __OUTTAB += "A"*17 + "O"*17 + "E"*11 + "U"*11 + "I"*5 + "Y"*5 + "D"*2
    __r = re.compile("|".join(__INTAB))
    __replaces_dict = dict(zip(__INTAB, __OUTTAB))
    result = __r.sub(lambda m: __replaces_dict[m.group(0)], s)
    return result

print(no_marks("Món hôm nay rất ngon và hấp dẫn"))
# Out:
# Mon hom nay rat ngon va hap dan

# %%
def normalize_text(text):

    #Remove các ký tự kéo dài: vd: đẹppppppp
    text = re.sub(r'([A-Z])\1+', lambda m: m.group(1).upper(), text, flags=re.IGNORECASE)

    # Chuyển thành chữ thường
    text = text.lower()

    #Chuẩn hóa tiếng Việt, xử lý emoj, chuẩn hóa tiếng Anh, thuật ngữ
    replace_list = {
        'òa': 'oà', 'óa': 'oá', 'ỏa': 'oả', 'õa': 'oã', 'ọa': 'oạ', 'òe': 'oè', 'óe': 'oé','ỏe': 'oẻ',
        'õe': 'oẽ', 'ọe': 'oẹ', 'ùy': 'uỳ', 'úy': 'uý', 'ủy': 'uỷ', 'ũy': 'uỹ','ụy': 'uỵ', 'uả': 'ủa',
        'ả': 'ả', 'ố': 'ố', 'u´': 'ố','ỗ': 'ỗ', 'ồ': 'ồ', 'ổ': 'ổ', 'ấ': 'ấ', 'ẫ': 'ẫ', 'ẩ': 'ẩ',
        'ầ': 'ầ', 'ỏ': 'ỏ', 'ề': 'ề','ễ': 'ễ', 'ắ': 'ắ', 'ủ': 'ủ', 'ế': 'ế', 'ở': 'ở', 'ỉ': 'ỉ',
        'ẻ': 'ẻ', 'àk': u' à ','aˋ': 'à', 'iˋ': 'ì', 'ă´': 'ắ','ử': 'ử', 'e˜': 'ẽ', 'y˜': 'ỹ', 'a´': 'á',
        #Quy các icon về 2 loại emoj: Tích cực hoặc tiêu cực
        "👹": "nagative", "👻": "positive", "💃": "positive",'🤙': ' positive ', '👍': ' positive ',
        "💄": "positive", "💎": "positive", "💩": "positive","😕": "nagative", "😱": "nagative", "😸": "positive",
        "😾": "nagative", "🚫": "nagative",  "🤬": "nagative","🧚": "positive", "🧡": "positive",'🐶':' positive ',
        '👎': ' nagative ', '😣': ' nagative ','✨': ' positive ', '❣': ' positive ','☀': ' positive ',
        '♥': ' positive ', '🤩': ' positive ', 'like': ' positive ', '💌': ' positive ',
        '🤣': ' positive ', '🖤': ' positive ', '🤤': ' positive ', ':(': ' nagative ', '😢': ' nagative ',
        '❤': ' positive ', '😍': ' positive ', '😘': ' positive ', '😪': ' nagative ', '😊': ' positive ',
        '?': ' ? ', '😁': ' positive ', '💖': ' positive ', '😟': ' nagative ', '😭': ' nagative ',
        '💯': ' positive ', '💗': ' positive ', '♡': ' positive ', '💜': ' positive ', '🤗': ' positive ',
        '^^': ' positive ', '😨': ' nagative ', '☺': ' positive ', '💋': ' positive ', '👌': ' positive ',
        '😖': ' nagative ', '😀': ' positive ', ':((': ' nagative ', '😡': ' nagative ', '😠': ' nagative ',
        '😒': ' nagative ', '🙂': ' positive ', '😏': ' nagative ', '😝': ' positive ', '😄': ' positive ',
        '😙': ' positive ', '😤': ' nagative ', '😎': ' positive ', '😆': ' positive ', '💚': ' positive ',
        '✌': ' positive ', '💕': ' positive ', '😞': ' nagative ', '😓': ' nagative ', '️🆗️': ' positive ',
        '😉': ' positive ', '😂': ' positive ', ':v': '  positive ', '=))': '  positive ', '😋': ' positive ',
        '💓': ' positive ', '😐': ' nagative ', ':3': ' positive ', '😫': ' nagative ', '😥': ' nagative ',
        '😃': ' positive ', '😬': ' 😬 ', '😌': ' 😌 ', '💛': ' positive ', '🤝': ' positive ', '🎈': ' positive ',
        '😗': ' positive ', '🤔': ' nagative ', '😑': ' nagative ', '🔥': ' nagative ', '🙏': ' nagative ',
        '🆗': ' positive ', '😻': ' positive ', '💙': ' positive ', '💟': ' positive ',
        '😚': ' positive ', '❌': ' nagative ', '👏': ' positive ', ';)': ' positive ', '<3': ' positive ',
        '🌝': ' positive ',  '🌷': ' positive ', '🌸': ' positive ', '🌺': ' positive ',
        '🌼': ' positive ', '🍓': ' positive ', '🐅': ' positive ', '🐾': ' positive ', '👉': ' positive ',
        '💐': ' positive ', '💞': ' positive ', '💥': ' positive ', '💪': ' positive ',
        '💰': ' positive ',  '😇': ' positive ', '😛': ' positive ', '😜': ' positive ',
        '🙃': ' positive ', '🤑': ' positive ', '🤪': ' positive ','☹': ' nagative ',  '💀': ' nagative ',
        '😔': ' nagative ', '😧': ' nagative ', '😩': ' nagative ', '😰': ' nagative ', '😳': ' nagative ',
        '😵': ' nagative ', '😶': ' nagative ', '🙁': ' nagative ', '< 3': 'positive',
        #dưới 3* quy về 1*, trên 3* quy về 5*
        '6 sao': ' 5star ','6 star': ' 5star ', '5star': ' 5star ','5 sao': ' 5star ','5sao': ' 5star ',
        'starstarstarstarstar': ' 5star ', '1 sao': ' 1star ', '1sao': ' 1star ','2 sao':' 1star ','2sao':' 1star ',
        '2 starstar':' 1star ','1star': ' 1star ', '0 sao': ' 1star ', '0star': ' 1star ',}

    for k, v in replace_list.items():
        text = text.replace(k, v)

    # chuyen punctuation thành space
    translator = str.maketrans(string.punctuation, ' ' * len(string.punctuation))
    text = text.translate(translator)

    text = ViTokenizer.tokenize(text)
    texts = text.split()
    len_text = len(texts)

    texts = [t.replace('_', ' ') for t in texts]
    for i in range(len_text):
        cp_text = texts[i]
        if cp_text in not_list: # Xử lý vấn đề phủ định 
            numb_word = 2 if len_text - i - 1 >= 4 else len_text - i - 1

            for j in range(numb_word):
                if texts[i + j + 1] in pos_list:
                    texts[i] = 'notpos'
                    texts[i + j + 1] = ''

                if texts[i + j + 1] in nag_list:
                    texts[i] = 'notnag'
                    texts[i + j + 1] = ''
        else:
            if cp_text in pos_list:
                texts.append('positive')
            elif cp_text in nag_list:
                texts.append('nagative')

    text = u' '.join(texts)

    text = text.replace(u'"', u' ')
    text = text.replace(u'️', u'')
    text = text.replace('🏻','')
    return text

# %%
class DataSource(object):

    def _load_raw_data(self, filename, is_train=True):

        a = []
        b = []

        regex = 'train_'
        if not is_train:
            regex = 'test_'

        with open(filename,  encoding="utf8") as file:
            for line in file:
                if regex in line:
                    b.append(a)
                    a = [line]
                elif line != '\n':
                    a.append(line)
        b.append(a)

        return b[1:]

    def _create_row(self, sample, is_train=True):

        d = {}
        d['id'] = sample[0].replace('\n', '')
        review = ""

        if is_train:
            for clause in sample[1:-1]:
                review += clause.replace('\n', ' ')
                review = review.replace('.', ' ')

            d['label'] = int(sample[-1].replace('\n', ' '))
        else:
            for clause in sample[1:]:
                review += clause.replace('\n', ' ')
                review = review.replace('.', ' ')


        d['review'] = review

        return d

    def load_data(self, filename, is_train=True):

        raw_data = self._load_raw_data(filename, is_train)
        lst = []

        for row in raw_data:
            lst.append(self._create_row(row, is_train))

        return lst

    def transform_to_dataset(self, x_set,y_set):
        X, y = [], []
        for document, topic in zip(list(x_set), list(y_set)):
            document = normalize_text(document)
            X.append(document.strip())
            y.append(topic)
            X.append(no_marks(document))
            y.append(topic)
        return X, y

# %%
ds = DataSource()
train_data = pd.DataFrame(ds.load_data('data_clean/train.crash'))
new_data = []

#Thêm mẫu bằng cách lấy trong từ điển Sentiment (nag/pos)
for index,row in enumerate(nag_list):
    new_data.append(['pos'+str(index),'0',row])
for index,row in enumerate(nag_list):
    new_data.append(['nag'+str(index),'1',row])

new_data = pd.DataFrame(new_data,columns=list(['id','label','review']))
train_data.append(new_data)
#print(new_data)
# Out:
#                id label                                             review
# 0    train_000000     0  "Dung dc sp tot cam on shop Đóng gói sản phẩm ...
# 1    train_000001     0  " Chất lượng sản phẩm tuyệt vời   Son mịn nhưn...
# 2    train_000002     0  " Chất lượng sản phẩm tuyệt vời nhưng k có hộp...
# 3    train_000003     1  ":(( Mình hơi thất vọng 1 chút vì mình đã kỳ v...
# 4    train_000004     1  "Lần trước mình mua áo gió màu hồng rất ok mà ...
# ..            ...   ...                                                ...
# 527        nag261     1                                               ế ẩm
# 528        nag262     1                                                  ế
# 529        nag263     1                                               sướt
# 530        nag264     1                                                dở
# 531        nag265     1
#
# [16606 rows x 3 columns]

# %%
stop_ws = (u'rằng',u'thì',u'là',u'mà',u'nhưng')

#cv = CountVectorizer(X_train,ngram_range=(1,5),stop_words=stop_ws)
#count_vector=cv.fit_transform(X_train)
#print(cv.vocabulary_)
#print(count_vector)

# %%
#pipe = Pipeline([('CountVectorizer', CountVectorizer(text,ngram_range=(1,5),stop_words=stop_ws)),
#                  ('tfidf', TfidfTransformer())]).fit(text)
#print(pipe['CountVectorizer'].transform(text).toarray())
#print(pipe['tfidf'].idf_)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_data.review, train_data.label, test_size=0.3,random_state=42)
X_train, y_train = ds.transform_to_dataset(X_train,y_train)
X_test, y_test = ds.transform_to_dataset(X_test, y_test)

steps = []
steps.append(('CountVectorizer', CountVectorizer(ngram_range=(1,5),stop_words=stop_ws,max_df=0.5, min_df=5)))
steps.append(('tfidf', TfidfTransformer(use_idf=False, sublinear_tf = True,norm='l2',smooth_idf=True)))
steps.append(('classifier', LinearSVC(fit_intercept = True,multi_class='crammer_singer', C=1)))
clf = Pipeline(steps)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
report1 = metrics.classification_report(y_test, y_pred, labels=[1,0], digits=3)
X_train, y_train = ds.transform_to_dataset(train_data.review, train_data.label)
print(report1)
# Out:
# /home/khanh/.local/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
#               precision    recall  f1-score   support
#
#            1      0.942     0.945     0.944      4508
#            0      0.952     0.949     0.950      5138
#
#     accuracy                          0.947      9646
#    macro avg      0.947     0.947     0.947      9646
# weighted avg      0.947     0.947     0.947      9646

# %%
#TRAIN OVERFITTING

clf.fit(X_train, y_train)
y_pred = clf.predict(X_train)
report2 = metrics.classification_report(y_train, y_pred, labels=[1,0], digits=3)

print(report2)
# Out:
#               precision    recall  f1-score   support
#
#            1      0.980     0.985     0.982     14768
#            0      0.987     0.983     0.985     17380
#
#     accuracy                          0.984     32148
#    macro avg      0.983     0.984     0.984     32148
# weighted avg      0.984     0.984     0.984     32148

# %%
#ERRO ANALYSIS
for id,x, y1, y2 in zip(train_data.id, X_train, y_train, y_pred):
    if y1 != y2:
        # CHECK EACH WRONG SAMPLE POSSITIVE/NAGATIVE
        #if y1!=1:#0:
        print(id,x, y1, y2)
# Out:
# train_000133 minh thoa vao ngon toc thay toc bi rit nen chi thoa vao phan chan mui thom nagative nagative 1 0
# train_000138 thời gian giao hàng rất nhanh cửa hàng phuc vụ quá qua tệ hang bị hư hại ma hong lời giai quyết người khác da the ma nguoi kia cũng vay hong chu đáo can xem xet lại khi mau hàng cửa hàng nay nha cac ban nagative nagative positive 0 1
# train_000139 thoi gian giao hang rat nhanh cua hang phuc vu qua qua te hang bi hu hai ma hong loi giai quyet nguoi khac da the ma nguoi kia cung vay hong chu dao can xem xet lai khi mau hang cua hang nay nha cac ban nagative nagative positive 0 1
# train_000204 ngọt quá cay quá ướt quá tạm được đúng với giá tiền nagative positive positive 1 0
# train_000205 ngot qua cay qua uot qua tam duoc dung voi gia tien nagative positive positive 1 0
# train_000258 ôi cái cấu hình đt mạnh kinh positive 1 0
# train_000348 17cu thì mua lg v10 vừa đẹp mà con dư tiền positive 1 0
# train_000687 lot mang to kha day doi duong kem cho trang nua thoi 0 1
# train_000734 tất quá xầu 1 0
# train_000830 hũ nhựa có nắp kép ở trong sạch sẽ positive 0 1
# train_000831 hu nhua co nap kep o trong sach se positive 0 1
# train_000864 nhỏ hơn màn hình gì 7 prime rất nhiều 0 1
# train_000865 nho hon man hinh gi 7 prime rat nhieu 0 1
# train_001010 điểm cộng cho son này là giá thành hạt dẻ mà màu sắc đa dạng tha hồ lựa chọn mình và bạn mình hốt luôn 2 cây mỗi đứa màu nào cũng ưng ý cả nhưng rất khuyến khích dùng kèm với son dưỡng vì son này làm khô môi điểm trừ mạnh là son dễ gãy cực cứ là phải nhẹ nhàng cực ấy còn nữa nếu để son bị nóng mình hay đãng để trên máy tính thì son như muốn tan chảy ra luôn vậy positive positive nagative positive nagative nagative 1 0
# train_001176 chưa mở ra xem không biết tn phí vận chuyển đắt 255k flash giảm 200k áp mã 100k coi như huề 2 154k không biết nấu tn nagative 0 1
# train_001177 chua mo ra xem khong biet tn phi van chuyen dat 255k flash giam 200k ap ma 100k coi nhu hue 2 154k khong biet nau tn nagative 0 1
# train_001383 van chuyen nhanh sua uong be tang notnag  positive 0 1
# train_001397 bong khong giong trong hinh nhung giao hang nhanh va be 0 1
# train_001488 dã dược doi sản phẩm khác dùng ok nhân viên bán hàng nhiệt tình positive positive 1 0
# train_001898 nguyentienthanh 7402 0 1
# train_001899 nguyentienthanh 7402 0 1
# train_001920 mật lỏg rót ly nhỏ để vào tủ lạnh chỉ bị đặc lại chứ không thấy lắg đườg tạm được đág với giá tiền nagative positive 0 1
# train_001921 mat log rot ly nho de vao tu lanh chi bi dac lai chu khong thay lag duog tam duoc dag voi gia tien nagative positive 0 1
# train_002005 son chuan nhung minh check code het han roi positive 1 0
# train_002151 hoan ho samsung giong nhu dang nghe ke chuyen co tich vay 0 1
# train_002250 hàng đẹp lắm nhưng góp ý với cửa hàng là notnag  sire sire notnag  đợt1 đặt 3 đôi màu đen sire to hơn bình thường h 1sire đợt2 đặt màu kem chung sire 35 hết mà có đôi to đôi nhỏ positive positive positive 0 1
# train_002270 hàng đẹp giao hàng hoi lâu positive nagative 1 0
# train_002271 hang dep giao hang hoi lau positive nagative 1 0
# train_002405 do gi sac lau het pin qua cho 5star nagative 0 1
# train_002420 gấu nâu đây ngắn hơn đây doremon nagative 0 1
# train_002466 hấp dẫn quá không e7 positive 0 1
# train_002467 hap dan qua khong e7 positive 0 1
# train_002498 tín hiệu đường truyền quá yếu không thể kết nối được máy tính sạc điện thoại vào yếu cửa hàng đóng gói thì ok mình sẽ nhận lô hàng này của cửa hàng để cải tiến thêm hi vọng sau cửa hàng kiểm tra kĩ nhé đóng gói sản phẩm rất đẹp và chắc chắn nagative positive nagative positive positive positive 1 0
# train_007560 dung duoc 2 ngay roi thay cung do tham positive nagative 0 1
# train_007610 cua hang nen nghi ban di la vua gian manh vua thoi 1 0
# train_007613 chiều dài vừa n phần cổ chân hơi rộng ik notnag  1 positive 0 1
# train_007691 giao hàng quá chậm trog thàh phố mà tận 4 ngày nhưng máy thì xài được nagative positive 0 1
# train_007692 giao hang qua cham trog thah pho ma tan 4 ngay nhung may thi xai duoc nagative positive 0 1
# train_007827 giày da cứng mang phỏng cả chân cỡ 35 đóng gói cẩn thận positive 1 0
# train_008069 đóng gói sản phẩm rất đẹp và chắc chắn chất lượng thì chưa dùng chưa biết thế nào hàng check được mã vạch positive positive positive positive 1 0
# train_008070 dong goi san pham rat dep va chac chan chat luong thi chua dung chua biet the nao hang check duoc ma vach positive positive positive positive 1 0
# train_008195 thấy phím thấm dầu là sản phẩm của nhật nên mình đã đặt mua luôn giấy dai thấm dầu khá tốt kích thước nhỏ gọn được khá nhiều người đánh giá là chất lượng tốt lại còn giá rẻ hơn một số loại ở thị trường nữa chứ đây là một sản phẩm nên mua positive positive positive positive positive 1 0
# train_008219 sản phẩm dùng ok một lưu ý nhỏ phần móc tay bằng chun bị sờn chỉ khi sử dụng ngay lần đầu positive nagative 0 1
# train_008220 san pham dung ok mot luu y nho phan moc tay bang chun bi son chi khi su dung ngay lan dau positive nagative 0 1
# train_008299 sạc không dây dễ quá mà 0 1
# train_008300 sac khong day de qua ma 0 1
# train_008391 kem thấm nhanh không rít notnag  bệt positive 0 1
# train_008392 kem tham nhanh khong rit notnag  bet positive 0 1
# train_008399 mk đọc rồi không hay lắm nhiều lúc cứ viết cái gì ấy chẳng liên quan đến bình thường s gì cả nhg đó là về quyển sách còn đâu thì cửa hàng phục vụ rất tốt chỉ bị móp đầu xíu thôi positive nagative nagative 0 1
# train_008400 mk doc roi khong hay lam nhieu luc cu viet cai gi ay chang lien quan den binh thuong s gi ca nhg do la ve quyen sach con dau thi cua hang phuc vu rat tot chi bi mop dau xiu thoi positive nagative nagative 0 1
# train_008507 tốc độ giao hàng sendo tuyệt vời đang đợi reback từ cửa hàng positive 1 0
# train_008508 toc do giao hang sendo tuyet voi dang doi reback tu cua hang positive 1 0
# train_008537 áo vừa vặn cơ mà bụng quần siêu chật nagative chun quần bé tí ti nagative 0 1
# train_008538 ao vua van co ma bung quan sieu chat nagative chun quan be ti ti nagative 0 1
# train_008606 chat luong banh va sot di kem kha ok tru viec 2 4 tui sot bi buc ra gan het thung hang nagative positive positive nagative 0 1
# train_008819 hang dom sac đuoc vai lan đa hong lien he voi cửa hàng đe bao hanh nhung cửa hàng không tra loi that la that vong qua đi dung la hang trung quoc hang dom 0 1
# train_008820 hang dom sac duoc vai lan da hong lien he voi cua hang de bao hanh nhung cua hang khong tra loi that la that vong qua di dung la hang trung quoc hang dom 0 1
# train_008918 đóng gói notnag  hàng bị chèn vỡ phần nhựa máy câu các khoen cần câu notnag  dán chắc chắn tạm được positive nagative positive positive positive 0 1
# train_008919 dong goi notnag  hang bi chen vo phan nhua may cau cac khoen can cau notnag  dan chac chan tam duoc positive nagative positive positive positive 0 1
# train_008978 lần đầu dùng thấy ok định đánh giá cho cửa hàng 5star nhưng đến lần thứ hai dùng thì bị giật điện với cái giá đó thì máy này là được rồi nhưng nhắn tin thái độ của cửa hàng như c í positive nagative positive 1 0
# train_009144 đóng gói notnag  hàng chấp nhận đươc positive 0 1
# train_009214 giao hàng nhanh đóng gói chắc chắn tuy nhiên cân notnag chính xác hơi  positive positive 1 0
# train_009215 giao hang nhanh dong goi chac chan tuy nhien can notnag chinh xac hoi  positive positive 1 0
# train_009405 cai chuoi nay notnag  vi hoi dai 2 canh ngan cu choc vao mat duoc cai mem mn mua nen can nhac loai cam tay hoac huou positive nagative positive 0 1
# train_009466 chất lượng sản phẩm ngọt positive 0 1
# train_009467 chat luong san pham ngot positive 0 1
# train_009616 giày bé hơn so với cỡ chuẩn positive 1 0
# train_009617 giay be hon so voi co chuan positive 1 0
# train_009738 giao thiếu cửa hàng da hoàn tiền nagative 0 1
# train_009739 giao thieu cua hang da hoan tien nagative 0 1
# train_009761 cần có quy định rõ ràng và xử phạt nghiêm minh với những trường hợp thi công gây mất an toàn cho người tham gia giao thông 0 1
# train_009762 can co quy dinh ro rang va xu phat nghiem minh voi nhung truong hop thi cong gay mat an toan cho nguoi tham gia giao thong 0 1
# train_009963 mỏng và nhẹ nagative 0 1
# train_009964 mong va nhe nagative 0 1
# train_010098 ban highlighter nay thi khong can phai ban toi roi highly recomended 0 1
# train_010162 xuong qua roi b oi anh het muon yeu em roi positive 1 0
# train_010193 để 1star vì mình nhận hàng cực lâu bên cửa hàng giao hàng nhanh nhưng bên vận chuyển mãi mới giao đồ ăn mà tận 1 tuần mới nhận được nagative lại còn chưa hề giao mà dám để là mìh hẹn lại ngày lấy nhưng may bù lại mực ngon giá cả hơ gì p lí sẽ ủng hộ cửa hàng tiếp nagative nagative positive positive positive 1 0
# train_010194 de 1star vi minh nhan hang cuc lau ben cua hang giao hang nhanh nhung ben van chuyen mai moi giao do an ma tan 1 tuan moi nhan duoc nagative lai con chua he giao ma dam de la mih hen lai ngay lay nhung may bu lai muc ngon gia ca ho gi p li se ung ho cua hang tiep nagative nagative positive positive positive 1 0
# train_010433 chất lượng sản phẩm tuyệt vời đóng gói sản phẩm rất đẹp và chắc chắn cửa hàng phục vụ rất tốt thời gian giao hàng chậm rất đáng tiền thời gian giao hàng chậm positive positive positive positive positive nagative nagative 1 0
# train_010434 chat luong san pham tuyet voi dong goi san pham rat dep va chac chan cua hang phuc vu rat tot thoi gian giao hang cham rat dang tien thoi gian giao hang cham positive positive positive positive positive nagative nagative 1 0
# train_010511 giày đẹp mà form giày thì hơi bị lỗi positive nagative nagative 1 0
# train_010512 giay dep ma form giay thi hoi bi loi positive nagative nagative 1 0
# train_010560 hop dung ok nhuung tui dung vua nhan keo khoa da hong roi positive nagative 1 0
# train_010641 lớp màu trên dây quai đeo trên bề mặt đồng hồ bị tróc vừa với giá nagative nagative 0 1
# train_010642 lop mau tren day quai deo tren be mat dong ho bi troc vua voi gia nagative nagative 0 1
# train_010789 mình đặt nhầm cho con ip8 nagative 0 1
# train_010790 minh dat nham cho con ip8 nagative 0 1
# train_010798 soi chi kha to dung rat kho khan neu manh hon thi se de su sung hon va bao ve ke rang tot hon gia cao hon chi nha khoa oral b nhung chat luong lai te hon nagative positive positive nagative 1 0
# train_010799 dán ốp vào như là màn hình xài hoa văn vậy lần đầu tiên bị trường hợp vậy đặt xuống chà muốn gãy tay toàn là bọt nước positive positive positive nagative nagative 0 1
# train_010800 dan op vao nhu la man hinh xai hoa van vay lan dau tien bi truong hop vay dat xuong cha muon gay tay toan la bot nuoc positive positive positive nagative nagative 0 1
# train_010909 đóng gói sản phẩm chắc chắn có điều táo hơi khô ăn mất ngon positive nagative positive 1 0
# train_010910 dong goi san pham chac chan co dieu tao hoi kho an mat ngon positive nagative positive 1 0
# train_010963 nhận rồi đã xài loại trà xanh mua dùng thử thay đổimùi lúa mạch thấy thơm notnag dùng  kia positive 0 1
# train_010964 nhan roi da xai loai tra xanh mua dung thu thay doimui lua mach thay thom notnag dung  kia positive 0 1
# train_010994 dong ho dep nhung day da rat te anh nhu hinh positive nagative 1 0
# train_011033 lần sau cửa hàng nên gói bỉm cẩn thận hơn positive 1 0
# train_011034 lan sau cua hang nen goi bim can than hon positive 1 0
# train_011093 sản phẩm duoc 0 1
# train_011184 cai sao z cua hang oi 0 1
# train_011209 chuột chạy được không biết xài được bao lâu đóng gói tệ chuột không có hộp của hãng chỉ được bọc trong bịch nilon hộp ngoài bị móp méo positive positive nagative positive nagative nagative 0 1
# train_011210 chuot chay duoc khong biet xai duoc bao lau dong goi te chuot khong co hop cua hang chi duoc boc trong bich nilon hop ngoai bi mop meo positive positive nagative positive nagative nagative 0 1
# train_011253 chất lượng sản phẩm tuyệt vời nhưng toàn chữ trung quốc positive positive 1 0
# train_011254 chat luong san pham tuyet voi nhung toan chu trung quoc positive positive 1 0
# train_011296 san pham tam duoc 0 1
# train_011341 chất lượng giấy tốt in màu đẹp phần trình bày cũng rõ ràng giải thích dễ hiểu có cả phần bài tập ứng dụng tuy nhiên phần chữ tiếng việt rất nhiều và mật độ chữ dày đặc thật dễ bị hoa mắt mà positive positive positive nagative 1 0
# train_011429 chất lương giấy tốt tuy nhiên đóng gói ẩu giao đến bao giấy rách hết nên giấy bị bẩn positive nagative nagative nagative 0 1
# train_011430 chat luong giay tot tuy nhien dong goi au giao den bao giay rach het nen giay bi ban positive nagative nagative nagative 0 1
# train_011433 hàng hết nhưng cửa hàng không thông báo để mình huỷ đơn hàng đến lúc lấy hàng về rồi mình mới biết thiếu 1 đôi giày mặc dù đã thanh toán đủ nhưng mk lại không đổi thành tiền mặt được và chậm chễ hàng của khách đặt nagative hi vọng cửa hàng sẽ rút kinh nghiệm nagative nagative positive nagative 0 1
# train_011434 hang het nhung cua hang khong thong bao de minh huy don hang den luc lay hang ve roi minh moi biet thieu 1 doi giay mac du da thanh toan du nhung mk lai khong doi thanh tien mat duoc va cham che hang cua khach dat nagative hi vong cua hang se rut kinh nghiem nagative nagative positive nagative 0 1
# train_013155 lam do choi cho con thoi dung la ham re lao vao ma mua b gi o moi thay xot tien mua cai ys 10 on hon mn ah positive positive 1 0
# train_013162 đóng gói sản phẩm rất đẹp và chắc chắn nhưng thiếu cây tháo mắc đồng hồ giao đồng hồ notnag  loại không làm ăn đàng hoàn thì mất khách nha cửa hàng positive positive nagative positive 1 0
# train_013163 dong goi san pham rat dep va chac chan nhung thieu cay thao mac dong ho giao dong ho notnag  loai khong lam an dang hoan thi mat khach nha cua hang positive positive nagative positive 1 0
# train_013168 miếng hơi mềm positive 1 0
# train_013169 mieng hoi mem positive 1 0
# train_013228 chụp bằng phần mềm này nước ảnh trong và tươi hơn cam của iphone nhưng có độ trễ chụp vật thể chuyển động sẽ bị nhoè không có chức năng làm mịn ảnh dùng phần mềm microsoft selfie thích hơn positive nagative positive positive 1 0
# train_013229 chup bang phan mem nay nuoc anh trong va tuoi hon cam cua iphone nhung co do tre chup vat the chuyen dong se bi nhoe khong co chuc nang lam min anh dung phan mem microsoft selfie thich hon positive nagative positive positive 1 0
# train_013238 đóng gói sản phẩm kỷ càng nhưng khui ra thì hộp đựng móp méo vỏ bảo vệ của sản phẩm bị nứt do va đập có thể do vận chuyển quăng ném nên mới bị vậy nagative nagative nagative 0 1
# train_013239 dong goi san pham ky cang nhung khui ra thi hop dung mop meo vo bao ve cua san pham bi nut do va dap co the do van chuyen quang nem nen moi bi vay nagative nagative nagative 0 1
# train_013285 nhu trong hình 0 1
# train_013286 nhu trong hinh 0 1
# train_013344 chất lượng sản phẩm tốt giao hàng nhanh nhưng vừa chia tay ny nên vote 1star nagative positive positive nagative 1 0
# train_013345 chat luong san pham tot giao hang nhanh nhung vua chia tay ny nen vote 1star nagative positive positive nagative 1 0
# train_013545 tốt mã rã đám sai số mỗ lần cân là 100 gam 1 0
# train_013553 tôi đã nhận hàng ngày thứ 2 16 07 2018 và mang về cắm điện nhưng hộp đựng đồng hồ chỉ chạy được một đêm đến sáng hôm sau thì động cơ không còn quay nữa và hiện đã ngưng hoạt động hoàn toàn tôi đã liên hệ tổng đài cửa hàng e để làm thủ tục trả lại hàng mong cửa hàng hỗ trợ cho bên cửa hàng e cám ơn positive positive 0 1
# train_013792 dong goi san pham rat dep va chac chan san pham khong giong hinh cua hang dang positive positive 1 0
# train_014121 chất lượng quá kém mới đeo 30 phút đã bị chậm mất 2 phút rồi positive positive positive positive positive nagative nagative 0 1
# train_014122 chat luong qua kem moi deo 30 phut da bi cham mat 2 phut roi positive positive positive positive positive nagative nagative 0 1
# train_014171 chưa sử dụng thử nên không biết kết quả thế nào thời gian giao hàng hơi lâu nagative 1 0
# train_014172 chua su dung thu nen khong biet ket qua the nao thoi gian giao hang hoi lau nagative 1 0
# train_014299 máy kiểm tra còn chống nước nhưng không dám thử positive 0 1
# train_014469 mình dùng suface pro 3 thấy chạy tốt mà đẹp hơn con này positive positive 1 0
# train_014470 minh dung suface pro 3 thay chay tot ma dep hon con nay positive positive 1 0
# train_014523 núm ti mình dốc ngược xuống thấy phun thành tia không biết bé sơ sinh bú có bị sặc không cửa hàng nagative 0 1
# train_014524 num ti minh doc nguoc xuong thay phun thanh tia khong biet be so sinh bu co bi sac khong cua hang nagative 0 1
# train_014638 nhin clip xe chay rat an tuong tuy nhien minh nghi co the cai tien them he thong ho tro se tot hon cho dieu kien duong lun sau positive 1 0
# train_014688 san pham phia sau rat ngan khac voi hinh duoc dang neu co nguoi ngoi phia sau se notnag che  neu di 1 nguoi thi ok nagative positive positive positive 1 0
# train_014784 khong e 2 khong e 4 khong e 5 da va dang su dung va se khong bao gio ngung su dung positive 0 1
# train_014826 tôi chả hiểu ý tưởng xây hầm ngầm vượt sông hồng để giải quyết ùn tắc là sao nữa 0 1
# train_014827 toi cha hieu y tuong xay ham ngam vuot song hong de giai quyet un tac la sao nua 0 1
# train_014996 cửa hàng gói hàng kĩ quá tr lun phía ngoài cửa hộp notnag   méo gì hết bomb cũng notnag  trầy xước gì hết vẫn nguyên vẹn positive positive positive 0 1
# train_014997 cua hang goi hang ki qua tr lun phia ngoai cua hop notnag   meo gi het bomb cung notnag  tray xuoc gi het van nguyen ven positive positive positive 0 1
# train_015111 re ghe nagative 0 1
# train_015286 hàng notnag như  mong muốn quá mỏng manh đóng gói sản phẩm rất đẹp và chắc chắn positive positive positive 1 0
# train_015287 hang notnag nhu  mong muon qua mong manh dong goi san pham rat dep va chac chan positive positive positive 1 0
# train_015539 khong tot 1 0
# train_015654 đóng gói sản phẩm rất đẹp và chắc chắn chất lượng sản phẩm tuyệt vời giao nhầm vị bạc hà sang vị nho notnag  positive positive positive positive nagative positive positive 1 0
# train_015655 dong goi san pham rat dep va chac chan chat luong san pham tuyet voi giao nham vi bac ha sang vi nho notnag  positive positive positive positive nagative positive positive 1 0
# train_015870 sản phẩm rất tốt nhưng có 1 điểm trừ là sản phẩm để 1 xíu là hết mùi notnag giữ  lâu cho lắm nhưng họp với giá tiền positive nagative positive nagative 1 0
# train_015871 san pham rat tot nhung co 1 diem tru la san pham de 1 xiu la het mui notnag giu  lau cho lam nhung hop voi gia tien positive nagative positive nagative 1 0
# train_015954 sao xit vao thay huong thom bay đi rat nhanh không giong như chao chảrm cua ban minh huong bình thường homw lâu cực nagative 0 1
# train_015955 sao xit vao thay huong thom bay di rat nhanh khong giong nhu chao charm cua ban minh huong binh thuong homw lau cuc nagative 0 1
# train_015965 hang rat ok se mua them nua khong phai hang notnag  kem khong an son ma la do cac ban khong tay te bao chet cho moi da khong tay thi da day son nao dinh noi vao moi cac ban minh xai va thay hai long muon doi moi san chac cac ban phai chiu kho 1 ty positive positive nagative positive 0 1

# %%
#CROSS VALIDATION
cross_score = cross_val_score(clf, X_train,y_train, cv=5)
print("CROSSVALIDATION 5 FOLDS: %0.4f (+/- %0.4f)" % (cross_score.mean(), cross_score.std() * 2))
# Out:
# /home/khanh/.local/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# CROSSVALIDATION 5 FOLDS: 0.9426 (+/- 0.0094)

# %%
test_list = []
text = input()
document = normalize_text(text)
test_list.append(document)
y_predict = clf.predict(test_list)
print(y_predict)
# Out:
# Đồ này cũng ngon nè
# [0]
